# %%
-
# Out:
# Input ===>
# ['0', '0', '0']
# Target ===>
# ['0', '0', '1']
# [[ 0.58947495]
#  [ 0.33348394]
#  [ 0.45613173]]
# Input ===>
# ['0', '0', '1']
# Target ===>
# ['0', '1', '0']
# [[ 0.51765389]
#  [ 0.3072732 ]
#  [ 0.51963683]]
# Input ===>
# ['0', '1', '0']
# Target ===>
# ['0', '1', '1']
# [[ 0.46652303]
#  [ 0.34178764]
#  [ 0.48080499]]
# Input ===>
# ['1', '0', '0']
# Target ===>
# ['0', '1', '1']
# [[ 0.4266962 ]
#  [ 0.39977075]
#  [ 0.48207898]]
# Input ===>
# ['0', '0', '0']
# Target ===>
# ['0', '0', '1']
# [[ 0.37355165]
#  [ 0.49242942]
#  [ 0.57764229]]
# Input ===>
# ['0', '0', '1']
# Target ===>
# ['0', '1', '0']
# [[ 0.32724898]
#  [ 0.4494591 ]
#  [ 0.61961408]]
# Input ===>
# ['0', '1', '0']
# Target ===>
# ['0', '1', '1']
# [[ 0.28892432]
#  [ 0.49575551]
#  [ 0.59416835]]
# Input ===>
# ['1', '0', '0']
# Target ===>
# ['0', '1', '1']
# [[ 0.28687605]
#  [ 0.53655255]
#  [ 0.57736017]]
# Input ===>
# ['0', '0', '0']
# Target ===>
# ['0', '0', '1']
# [[ 0.26703692]
# ...
